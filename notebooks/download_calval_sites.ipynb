# %%
import os
from pathlib import Path
import ast
import earthaccess
import pandas as pd
import geopandas as gpd
from shapely.geometry import Polygon

# %%
def _earthacess_authenticate():
    env_list = ["EARTHDATA_USERNAME", "EARTHDATA_PASSWORD"]
    netrc_path = Path.home() / ".netrc"
    persist = False

    # Check if envs are set
    if all(var in os.environ for var in env_list):
        strategy = 'environment'
    # Check if .netcdf exist in home dir
    elif netrc_path.exists():
        strategy ='netcdf'
    # Enter in interactive mode
    else:
        strategy="interactive"
        persist=True

    # Login to earthdata access
    print(f'Login in to earthdata with: {strategy}')
    auth = earthaccess.login(strategy=strategy, persist=persist)
    if auth.authenticated:
        print('Authentication success!')
    else:
        print('Authentication failed!')
    return auth

# %%
auth = _earthacess_authenticate()
# Out:
# Login in to earthdata with: netcdf
# Authentication success!

# %%
output_directory = Path('/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval')
start_date = '2025-03-01T00:00:00'
end_date = '2025-05-01T00:00:00'
swot_l3_type='*_100m_*'

# %% [markdown]
# # MIAMI

# %%
asc_id = '132_055F'
dsc_id = '091_100F' #369_100F

# %%
out = output_directory / 'Miami'
out.mkdir(exist_ok=True)

# %%
result = [earthaccess.search_data(short_name='SWOT_L2_HR_Raster_2.0',
                        temporal=('2025-03-13T00:00:00', '2025-05-16T00:00:00'),
                        granule_name=f'*_100m*_{ix}*') for ix in ['132_055F', '091_100F', '369_100F']]

result = [ix for ix in result if len(ix)>0]
flat_list = [item for sublist in result for item in sublist]

# %%
earthaccess.download(flat_list, local_path= out)
# Out:
# QUEUEING TASKS | : 100%|██████████| 3/3 [00:00<00:00, 776.00it/s]
# PROCESSING TASKS | : 100%|██████████| 3/3 [00:06<00:00,  2.02s/it]
# COLLECTING RESULTS | : 100%|██████████| 3/3 [00:00<00:00, 27413.75it/s]
# ['/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Miami/SWOT_L2_HR_Raster_100m_UTM17R_N_x_x_x_030_132_055F_20250321T235840_20250321T235900_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Miami/SWOT_L2_HR_Raster_100m_UTM17R_N_x_x_x_030_091_100F_20250320T130424_20250320T130445_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Miami/SWOT_L2_HR_Raster_100m_UTM17R_N_x_x_x_031_091_100F_20250410T094928_20250410T094949_PIC2_01.nc']

# %% [markdown]
# ## NEW ORLEANS

# %%
out = output_directory / 'New_Orleans'
out.mkdir(exist_ok=True)

result = [earthaccess.search_data(short_name='SWOT_L2_HR_Raster_2.0',
                        temporal=('2025-03-13T00:00:00', '2025-05-16T00:00:00'),
                        granule_name=f'*_100m*_{ix}*') for ix in ['203_104','509_104', '522_051', '244_051']]

result = [ix for ix in result if len(ix)>0]
flat_list = [item for sublist in result for item in sublist]

# %%
earthaccess.download(flat_list, local_path= out)
# Out:
# QUEUEING TASKS | : 100%|██████████| 6/6 [00:00<00:00, 329.20it/s]
# PROCESSING TASKS | : 100%|██████████| 6/6 [00:05<00:00,  1.05it/s]
# COLLECTING RESULTS | : 100%|██████████| 6/6 [00:00<00:00, 53773.13it/s]
# ['/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/New_Orleans/SWOT_L2_HR_Raster_100m_UTM16R_N_x_x_x_030_203_104F_20250324T130748_20250324T130809_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/New_Orleans/SWOT_L2_HR_Raster_100m_UTM15R_N_x_x_x_029_509_104F_20250314T144531_20250314T144552_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/New_Orleans/SWOT_L2_HR_Raster_100m_UTM15R_N_x_x_x_030_509_104F_20250404T113034_20250404T113055_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/New_Orleans/SWOT_L2_HR_Raster_100m_UTM16R_N_x_x_x_029_522_051F_20250315T013636_20250315T013657_PIC2_01.nc',
# ...

# %% [markdown]
# # Norfolk

# %%
out = output_directory / 'Norfolk'
out.mkdir(exist_ok=True)

result = [earthaccess.search_data(short_name='SWOT_L2_HR_Raster_2.0',
                        temporal=('2025-02-13T00:00:00', '2025-05-16T00:00:00'),
                        granule_name=f'*_100m*_{ix}*') for ix in ['064_110F', '369_110', '048_045', '354_045']]

result = [ix for ix in result if len(ix)>0]
flat_list = [item for sublist in result for item in sublist]

# %%
flat_list
# Out:
# [Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_Raster_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Latitude': 36.59518831179102, 'Longitude': -77.74050645113925}, {'Latitude': 36.35099280753312, 'Longitude': -76.34464373447729}, {'Latitude': 37.474717686090116, 'Longitude': -76.02686463790828}, {'Latitude': 37.72449613923345, 'Longitude': -77.44195144649237}, {'Latitude': 36.59518831179102, 'Longitude': -77.74050645113925}]}}], 'BoundingRectangles': [{'WestBoundingCoordinate': -77.74050645113925, 'SouthBoundingCoordinate': 36.35099280753312, 'EastBoundingCoordinate': -76.02686463790828, 'NorthBoundingCoordinate': 37.72449613923345}]}, 'Track': {'Cycle': 28, 'Passes': [{'Pass': 369, 'Tiles': ['218L', '219L', '220L', '221L', '218R', '219R', '220R', '221R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2025-02-16T18:00:13.033Z', 'BeginningDateTime': '2025-02-16T17:59:51.939Z'}}
# ...

# %%
earthaccess.download(flat_list, local_path= out)
# Out:
# QUEUEING TASKS | : 100%|██████████| 6/6 [00:00<00:00, 315.08it/s]
# PROCESSING TASKS | : 100%|██████████| 6/6 [00:09<00:00,  1.52s/it]
# COLLECTING RESULTS | : 100%|██████████| 6/6 [00:00<00:00, 53092.46it/s]
# ['/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Norfolk/SWOT_L2_HR_Raster_100m_UTM18S_N_x_x_x_028_369_110F_20250216T175951_20250216T180013_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Norfolk/SWOT_L2_HR_Raster_100m_UTM18S_N_x_x_x_029_369_110F_20250309T144455_20250309T144516_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Norfolk/SWOT_L2_HR_Raster_100m_UTM18S_N_x_x_x_030_369_110F_20250330T113000_20250330T113021_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Norfolk/SWOT_L2_HR_Raster_100m_UTM18S_N_x_x_x_028_354_045F_20250216T044626_20250216T044647_PIC2_01.nc',
# ...

# %% [markdown]
# # New York

# %%
out = output_directory / 'New_York'
out.mkdir(exist_ok=True)

result = [earthaccess.search_data(short_name='SWOT_L2_HR_Raster_2.0',
                        temporal=('2025-02-13T00:00:00', '2025-05-16T00:00:00'),
                        granule_name=f'*_100m*_{ix}*') for ix in ['020_042', '341_113', '063_113']]

result = [ix for ix in result if len(ix)>0]
flat_list = [item for sublist in result for item in sublist]

# %%
flat_list
# Out:
# [Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_Raster_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Latitude': 41.10389869268857, 'Longitude': -72.96048454968255}, {'Latitude': 40.83562126846454, 'Longitude': -74.4394071781963}, {'Latitude': 39.71714302692734, 'Longitude': -74.08144039424994}, {'Latitude': 39.97894754823607, 'Longitude': -72.62487146386567}, {'Latitude': 41.10389869268857, 'Longitude': -72.96048454968255}]}}], 'BoundingRectangles': [{'WestBoundingCoordinate': -74.4394071781963, 'SouthBoundingCoordinate': 39.71714302692734, 'EastBoundingCoordinate': -72.62487146386567, 'NorthBoundingCoordinate': 41.10389869268857}]}, 'Track': {'Cycle': 29, 'Passes': [{'Pass': 20, 'Tiles': ['082L', '083L', '082R', '083R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2025-02-25T03:07:20.595Z', 'BeginningDateTime': '2025-02-25T03:07:12.130Z'}}
#  Size(MB): 41.90677547454834
# ...

# %%
earthaccess.download(flat_list, local_path= out)
# Out:
# QUEUEING TASKS | : 100%|██████████| 10/10 [00:00<00:00, 488.77it/s]
# PROCESSING TASKS | : 100%|██████████| 10/10 [00:06<00:00,  1.50it/s]
# COLLECTING RESULTS | : 100%|██████████| 10/10 [00:00<00:00, 122640.47it/s]
# ['/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/New_York/SWOT_L2_HR_Raster_100m_UTM18T_N_x_x_x_029_020_042F_20250225T030712_20250225T030720_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/New_York/SWOT_L2_HR_Raster_100m_UTM18T_N_x_x_x_030_020_042F_20250317T235216_20250317T235224_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/New_York/SWOT_L2_HR_Raster_100m_UTM18T_N_x_x_x_031_020_042F_20250407T203720_20250407T203728_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/New_York/SWOT_L2_HR_Raster_100m_UTM18T_N_x_x_x_028_341_113F_20250215T180033_20250215T180041_PIC2_01.nc',
# ...

# %% [markdown]
# # Tokyo

# %%
out = output_directory / 'Tokyo'
out.mkdir(exist_ok=True)

result = [earthaccess.search_data(short_name='SWOT_L2_HR_Raster_2.0',
                        temporal=('2025-02-13T00:00:00', '2025-05-16T00:00:00'),
                        granule_name=f'*_100m*_{ix}*') for ix in ['241_109', '241_108', '532_046', '532_047']]

result = [ix for ix in result if len(ix)>0]
flat_list = [item for sublist in result for item in sublist]

# %%
flat_list
# Out:
# [Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_Raster_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Latitude': 35.46460890403489, 'Longitude': 138.95794378129395}, {'Latitude': 35.225727504637376, 'Longitude': 140.33553458096333}, {'Latitude': 36.350992807533125, 'Longitude': 140.64165764152224}, {'Latitude': 36.59518831179102, 'Longitude': 139.24579492486026}, {'Latitude': 35.46460890403489, 'Longitude': 138.95794378129395}]}}], 'BoundingRectangles': [{'WestBoundingCoordinate': 138.95794378129392, 'SouthBoundingCoordinate': 35.225727504637376, 'EastBoundingCoordinate': 140.64165764152222, 'NorthBoundingCoordinate': 36.59518831179102}]}, 'Track': {'Cycle': 29, 'Passes': [{'Pass': 241, 'Tiles': ['216L', '217L', '218L', '219L', '216R', '217R', '218R', '219R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2025-03-05T00:59:43.305Z', 'BeginningDateTime': '2025-03-05T00:59:22.216Z'}}
# ...

# %%
earthaccess.download(flat_list, local_path= out)
# Out:
# QUEUEING TASKS | : 100%|██████████| 10/10 [00:00<00:00, 625.22it/s]
# PROCESSING TASKS | : 100%|██████████| 10/10 [00:04<00:00,  2.13it/s]
# COLLECTING RESULTS | : 100%|██████████| 10/10 [00:00<00:00, 85077.16it/s]
# ['/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Tokyo/SWOT_L2_HR_Raster_100m_UTM54S_N_x_x_x_029_241_109F_20250305T005922_20250305T005943_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Tokyo/SWOT_L2_HR_Raster_100m_UTM54S_N_x_x_x_030_241_109F_20250325T214427_20250325T214448_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Tokyo/SWOT_L2_HR_Raster_100m_UTM54S_N_x_x_x_029_241_108F_20250305T005919_20250305T005923_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Tokyo/SWOT_L2_HR_Raster_100m_UTM54S_N_x_x_x_030_241_108F_20250325T214424_20250325T214428_PIC2_01.nc',
# ...

# %% [markdown]
# # ALASKA

# %%
out = output_directory / 'Alaska'
out.mkdir(exist_ok=True)

result = [earthaccess.search_data(short_name='SWOT_L2_HR_Raster_2.0',
                        temporal=('2025-02-13T00:00:00', '2025-05-16T00:00:00'),
                        granule_name=f'*_100m*_{ix}*') for ix in ['470_023', '459_132']]

result = [ix for ix in result if len(ix)>0]
flat_list = [item for sublist in result for item in sublist]

# %%
earthaccess.download(flat_list, local_path= out)
# Out:
# QUEUEING TASKS | : 100%|██████████| 6/6 [00:00<00:00, 351.46it/s]
# PROCESSING TASKS | : 100%|██████████| 6/6 [00:03<00:00,  1.56it/s]
# COLLECTING RESULTS | : 100%|██████████| 6/6 [00:00<00:00, 51046.30it/s]
# ['/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Alaska/SWOT_L2_HR_Raster_100m_UTM06V_N_x_x_x_028_470_023F_20250220T080657_20250220T080718_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Alaska/SWOT_L2_HR_Raster_100m_UTM06V_N_x_x_x_029_470_023F_20250313T045201_20250313T045222_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Alaska/SWOT_L2_HR_Raster_100m_UTM06V_N_x_x_x_030_470_023F_20250403T013704_20250403T013725_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Alaska/SWOT_L2_HR_Raster_100m_UTM06V_N_x_x_x_028_459_132F_20250219T231726_20250219T231747_PIC2_01.nc',
# ...

# %% [markdown]
# # GREENLAND

# %%
out = output_directory / 'Greenland'
out.mkdir(exist_ok=True)

result = [earthaccess.search_data(short_name='SWOT_L2_HR_Raster_2.0',
                        temporal=('2025-02-13T00:00:00', '2025-05-16T00:00:00'),
                        granule_name=f'*_100m*_{ix}*') for ix in ['434_024', '423_131']]

result = [ix for ix in result if len(ix)>0]
flat_list = [item for sublist in result for item in sublist]

# %%
flat_list
# Out:
# [Collection: {'Version': '2.0', 'ShortName': 'SWOT_L2_HR_Raster_2.0'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Latitude': 59.828627378695295, 'Longitude': -46.305172137663774}, {'Latitude': 59.37807203028166, 'Longitude': -44.21977081032338}, {'Latitude': 60.42238565653312, 'Longitude': -43.27349570802251}, {'Latitude': 60.89021061295775, 'Longitude': -45.41120540635986}, {'Latitude': 59.828627378695295, 'Longitude': -46.305172137663774}]}}], 'BoundingRectangles': [{'WestBoundingCoordinate': -46.30517213766376, 'SouthBoundingCoordinate': 59.37807203028166, 'EastBoundingCoordinate': -43.273495708022494, 'NorthBoundingCoordinate': 60.89021061295775}]}, 'Track': {'Cycle': 28, 'Passes': [{'Pass': 423, 'Tiles': ['261L', '262L', '263L', '261R', '262R', '263R']}]}}}
#  Temporal coverage: {'RangeDateTime': {'EndingDateTime': '2025-02-18T16:25:21.774Z', 'BeginningDateTime': '2025-02-18T16:25:04.184Z'}}
# ...

# %%
earthaccess.download(flat_list, local_path= out)
# Out:
# QUEUEING TASKS | : 100%|██████████| 3/3 [00:00<00:00, 896.41it/s]
# PROCESSING TASKS | : 100%|██████████| 3/3 [00:03<00:00,  1.30s/it]
# COLLECTING RESULTS | : 100%|██████████| 3/3 [00:00<00:00, 37786.52it/s]
# ['/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Greenland/SWOT_L2_HR_Raster_100m_UTM23V_N_x_x_x_028_423_131F_20250218T162504_20250218T162521_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Greenland/SWOT_L2_HR_Raster_100m_UTM23V_N_x_x_x_029_423_131F_20250311T131007_20250311T131025_PIC2_01.nc',
#  '/u/aurora-r0/govorcin/01_OPERA/DSWx_SWOT/notebooks/data/calval/Greenland/SWOT_L2_HR_Raster_100m_UTM23V_N_x_x_x_030_423_131F_20250401T095511_20250401T095529_PIC2_01.nc']
